# %%
# Importing the necessary module
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import statistics as stats
# %matplotlib inline

# %%
# Loading the tips dataset
df_tips = sns.load_dataset('tips')
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Mean, Median & mode
print(np.mean(df_tips['total_bill']))
print(np.median(df_tips['total_bill']))
print(stats.mode(df_tips['total_bill']))
# Out:
# 19.785942622950824
# 17.795
# 13.42

# %%
# summary statistics
df_tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Box Plot
sns.boxplot(x = df_tips['total_bill'])
plt.show()

# %%
sns.histplot(x=df_tips['total_bill'], kde=True)
plt.show()

# %%
df_iris = sns.load_dataset('iris')
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# sns.histplot(x=df_iris.sepal_length, kde=True)
sns.histplot(x=df_iris['sepal_length'], kde=True)
plt.show()

# %%
# sepal width follow the gausian distribution
sns.histplot(x=df_iris['sepal_width'], kde=True)
plt.show()

# %%
sns.countplot(x = df_iris.species)
plt.show()

# %%
np.percentile(df_iris['sepal_length'], [25, 50, 75])
# Out:
# array([5.1, 5.8, 6.4])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

iris = sns.load_dataset('iris')

fig, axs = plt.subplots(ncols=4, figsize=(18, 6))

sns.boxplot(data=iris, x='species', y='sepal_length', ax=axs[0])
sns.boxplot(data=iris, x='species', y='sepal_width', ax=axs[1])
sns.boxplot(data=iris, x='species', y='petal_length', ax=axs[2])
sns.boxplot(data=iris, x='species', y='petal_width', ax=axs[3])

plt.show()
